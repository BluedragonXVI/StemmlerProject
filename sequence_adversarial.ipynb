# %%
import pandas as pd
import numpy as np
import re
import tqdm
import pickle

import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import GPT2Model
from utils import *

# %%
from icd9cms.icd9 import search

with open("./data/pcode_dict.txt", "rb") as fp: 
    icd9_pcode_dict = pickle.load(fp)

# %%
NTDBGPT2_lm = AutoModelForCausalLM.from_pretrained('dracoglacius/NTDB-GPT2')
NTDBGPT2_tokenizer = AutoTokenizer.from_pretrained('dracoglacius/NTDB-GPT2')
NTDBGPT2_embed = GPT2Model.from_pretrained('dracoglacius/NTDB-GPT2')
# Out:
# Some weights of the model checkpoint at dracoglacius/NTDB-GPT2 were not used when initializing GPT2Model: ['lm_head.weight']
# - This IS expected if you are initializing GPT2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing GPT2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ## ECodes
#
# * E812.0 = Other motor vehicle traffic accident involving collision with motor vehicle injuring driver of motor vehicle other than motorcycle.
# * E885.9 = Accidental fall from other slipping tripping or stumbling
# * E966.0 = Assault by cutting and piercing instrument

# %%
trn_seq = np.load("./data/25k_train_seqs_3_22_E8859_E8120_E9660_E9654_E9240.npy")

# %%
trn_seq
# Out:
# array(['<START> E885.9 <DSTART> 853.00 873.0 <PSTART> 01.39 <END>',
#        '<START> E885.9 <DSTART> 820.21 812.01 <PSTART> 79.01 00.33 79.35 <END>',
#        '<START> E885.9 <DSTART> 831.01 812.09 <PSTART> <UNK> <END>', ...,
#        '<START> E924.0 <DSTART> 948.00 <PSTART> 86.28 <END>',
#        '<START> E924.0 <DSTART> 948.00 945.26 842.13 <PSTART>  <END>',
#        '<START> E924.0 <DSTART> 948 944.37 944.36 944.32 944.31 943.31 <PSTART>  <END>'],
#       dtype='<U622')

# %% [markdown]
# ## Separate Data
#
# #### Training Data is In Domain Data

# %%
e8120_trn_seq = [x for x in trn_seq if 'E812.0' in x] # 5000 items
e8859_trn_seq = [x for x in trn_seq if 'E885.9' in x] # 5000 items
e9660_trn_seq = [x for x in trn_seq if 'E966.0' in x] # 5000 items
e9654_trn_seq = [x for x in trn_seq if 'E965.4' in x] # 5000 items
e9240_trn_seq = [x for x in trn_seq if 'E924.0' in x] # 5000 items

# %% [markdown]
# #### From the Training Data Create Adversarial Examples

# %%
def print_seq_dsc(seq):
    cds = seq.split()
    tp = 'START'
    for c in cds:
        if c == '<START>':
            print('=' * 9 + ' START ' + '=' * 9)
        elif c == '<DSTART>':
            tp = 'DX'
            print('=' * 10 + ' DXS ' + '=' * 10)
        elif c == '<PSTART>':
            tp = 'PR'
            print('=' * 10 + ' PRS ' + '=' * 10)
        elif c == '<END>':
            print('=' * 10 + ' END ' + '=' * 10)
        elif c == '<UNK>':
            print(f'{c}:Unknown Code')
        else:
            if tp == 'DX':
                print(search(c))
            if tp == 'PR':
                pr_cd = re.sub(r'\.', '', c)
                if pr_cd in icd9_pcode_dict:
                    print(f"{pr_cd}:{icd9_pcode_dict[pr_cd]}")
                else:
                    print(f'{pr_cd}:Unknown Code')

# %%
def print_seqs(seqs):
    for seq in seqs:
        print_seq_dsc(seq)
        print()

# %%
print_seqs(e8120_trn_seq[:100])
# Out:
# ========= START =========
# ========== DXS ==========
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 80702:Fracture two ribs-closed:Closed fracture of two ribs
# ========== PRS ==========
# 9352:Application of neck support
# 8801:Computerized axial tomography of abdomen
# 8741:Computerized axial tomography of thorax
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# 8798:Open wound site NOS:Open wound(s) (multiple) of unspecified site(s), without mention of complication
# 8509:Concussion NOS:Concussion, unspecified
# 82525:Fx metatarsal-closed:Closed fracture of metatarsal bone(s)
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 79311:Solitary pulmonry nodule:Solitary pulmonary nodule
# 83304:Disloc carpometacarp-cl:Closed dislocation of carpometacarpal (joint)
# 7856:Enlargement lymph nodes:Enlargement of lymph nodes
# 784:Symptoms involving head and neck:None
# 7339:Other and unspecified disorders of bone and cartilage:None
# 733:Other disorders of bone and cartilage:None
# 721:Spondylosis and allied disorders:None
# 428:Heart failure:None
# 42769:Premature beats NEC:Other premature beats
# 4263:Left bb block NEC:Other left bundle branch block
# 4148:Chr ischemic hrt dis NEC:Other specified forms of chronic ischemic heart disease
# 414:Other forms of chronic ischemic heart disease:None
# 412:Old myocardial infarction:None
# 4019:Hypertension NOS:Unspecified essential hypertension
# 2989:Psychosis NOS:Unspecified psychosis
# 2886:Elevated white blood cell count:None
# 2724:Hyperlipidemia NEC/NOS:Other and unspecified hyperlipidemia
# 2449:Hypothyroidism NOS:Unspecified acquired hypothyroidism
# ========== PRS ==========
# 7974:Closed reduction of dislocation of hand and finger
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 87340:Open wound of face NOS:Open wound of face, unspecified site, without mention of complication
# 8509:Concussion NOS:Concussion, unspecified
# ========== PRS ==========
# 8703:Computerized axial tomography of head
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 87342:Open wound of forehead:Open wound of forehead, without mention of complication
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 92411:Contusion of knee:Contusion of knee
# 8245:Fx bimalleolar-open:Bimalleolar fracture, open
# ========== PRS ==========
# 7966:Debridement of open fracture site, tibia and fibula
# 7936:Open reduction of fracture with internal fixation, tibia and fibula
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9130:Abrasion forearm:Abrasion or friction burn of elbow, forearm, and wrist, without mention of infection
# 9120:Abrasion shoulder/arm:Abrasion or friction burn of shoulder and upper arm, without mention of infection
# 86121:Lung contusion-closed:Contusion of lung without mention of open wound into thorax
# 8449:Sprain of knee & leg NOS:Sprains and strains of unspecified site of knee and leg
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 80700:Fracture rib NOS-closed:Closed fracture of rib(s), unspecified
# 920:Contusion of face, scalp, and neck except eye(s):None
# 80843:Pelv fx-clos/pelv disrup:Multiple closed pelvic fractures with disruption of pelvic circle
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# ========== PRS ==========
# 7939:Open reduction of fracture with internal fixation, other specified bone
# 3829:Other diagnostic procedures on blood vessels
# 3888:Other surgical occlusion of vessels, lower limb arteries
# 8849:Arteriography of other specified sites
# 3999:Other operations on vessels
# 8314:Fasciotomy
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8470:Sprain of neck:Sprain of neck
# 8471:Sprain thoracic region:Sprain of thoracic
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9221:Contusion of chest wall:Contusion of chest wall
# 8730:Open wound of scalp:Open wound of scalp, without mention of complication
# 8509:Concussion NOS:Concussion, unspecified
# 81500:Fx metacarpal NOS-closed:Closed fracture of metacarpal bone(s), site unspecified
# ========== PRS ==========
# 8703:Computerized axial tomography of head
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# 8838:Other computerized axial tomography
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 86121:Lung contusion-closed:Contusion of lung without mention of open wound into thorax
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 82332:Fx shaft tibia w fib-opn:Open fracture of shaft of fibula with tibia
# 80703:Fracture three ribs-clos:Closed fracture of three ribs
# ========== PRS ==========
# 8659:Closure of skin and subcutaneous tissue of other sites
# 7936:Open reduction of fracture with internal fixation, tibia and fibula
# 8622:Excisional debridement of wound, infection, or burn
# 796:Unknown Code
# 9904:Transfusion of packed cells
# 8872:Diagnostic ultrasound of heart
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9100:Abrasion head:Abrasion or friction burn of face, neck, and scalp except eye, without mention of infection
# 88100:Open wound of forearm:Open wound of forearm, without mention of complication
# 85200:Traum subarachnoid hem:Subarachnoid hemorrhage following injury without mention of open intracranial wound, unspecified state of consciousness
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 86405:Liver lacerat unspcf cls:Injury to liver without mention of open wound into cavity laceration, unspecified
# 83942:Dislocat sacrum-closed:Closed dislocation, sacrum
# 8080:Fracture acetabulum-clos:Closed fracture of acetabulum
# 80841:Fracture of ilium-closed:Closed fracture of ilium
# 86600:Kidney injury NOS-closed:Injury to kidney without mention of open wound into cavity, unspecified injury
# 8509:Concussion NOS:Concussion, unspecified
# ========== PRS ==========
# 9344:Other skeletal traction
# 7909:Closed reduction of fracture without internal fixation, other specified bone
# 7939:Open reduction of fracture with internal fixation, other specified bone
# 7989:Open reduction of dislocation of other specified sites
# 9904:Transfusion of packed cells
# 9907:Transfusion of other serum
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 82101:Fx femur shaft-closed:Closed fracture of shaft of femur
# ========== PRS ==========
# 8801:Computerized axial tomography of abdomen
# 9346:Other skin traction of limbs
# 8838:Other computerized axial tomography
# 8826:Other skeletal x-ray of pelvis and hip
# 8827:Skeletal x-ray of thigh, knee, and lower leg
# 7915:Closed reduction of fracture with internal fixation, femur
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9110:Abrasion trunk:Abrasion or friction burn of trunk, without mention of infection
# 9100:Abrasion head:Abrasion or friction burn of face, neck, and scalp except eye, without mention of infection
# 85011:Concus-brief coma <31 mn:Concussion, with loss of consciousness of 30 minutes or less
# ========== PRS ==========
# 8826:Other skeletal x-ray of pelvis and hip
# 8838:Other computerized axial tomography
# 8744:Routine chest x-ray, so described
# 8827:Skeletal x-ray of thigh, knee, and lower leg
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8730:Open wound of scalp:Open wound of scalp, without mention of complication
# 8500:Concussion w/o coma:Concussion with no loss of consciousness
# ========== PRS ==========
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# 8838:Other computerized axial tomography
# 8838:Other computerized axial tomography
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 86601:Kidney hematoma-closed:Injury to kidney without mention of open wound into cavity, hematoma without rupture of capsule
# 86504:Spleen disruption-clos:Injury to spleen without mention of open wound into cavity, massive parenchymal disruption
# 86404:Liver laceration, major:Injury to liver without mention of open wound into cavity, laceration, major
# 86122:Lung laceration-closed:Laceration of lung without mention of open wound into thorax
# 85306:Brain hem NEC-coma NOS:Other and unspecified intracranial hemorrhage following injury without mention of open intracranial wound, with loss of consciousness of unspecified duration
# 85226:Subdural hemorr-coma NOS:Subdural hemorrhage following injury without mention of open intracranial wound, with loss of consciousness of unspecified duration
# 80843:Pelv fx-clos/pelv disrup:Multiple closed pelvic fractures with disruption of pelvic circle
# 80708:Fx eight/more rib-closed:Closed fracture of eight or more ribs
# 80126:Cl skul base fx-coma NOS:Closed fracture of base of skull with subarachnoid, subdural, and extradural hemorrhage, with loss of consciousness of unspecified duration
# ========== PRS ==========
# 9907:Transfusion of other serum
# 5061:Closure of laceration of liver
# 5499:Other operations of abdominal region
# 9904:Transfusion of packed cells
# 5472:Other repair of abdominal wall
# 5411:Exploratory laparotomy
# 3492:Injection into thoracic cavity
# 3404:Insertion of intercostal catheter for drainage
# 415:Total splenectomy
# 3343:Closure of laceration of lung
# 9971:Therapeutic plasmapheresis
# 3409:Other incision of pleura
# 9907:Transfusion of other serum
# 9905:Transfusion of platelets
# 9904:Transfusion of packed cells
# 8659:Closure of skin and subcutaneous tissue of other sites
# 996:Unknown Code
# 8964:Pulmonary artery wedge monitoring
# 9904:Transfusion of packed cells
# 3324:Closed [endoscopic] biopsy of bronchus
# 3891:Arterial catheterization
# 9904:Transfusion of packed cells
# 9605:Other intubation of respiratory tract
# 9357:Application of other wound dressing
# 5411:Exploratory laparotomy
# 9785:Removal of packing from trunk, not elsewhere classified
# 5472:Other repair of abdominal wall
# 8741:Computerized axial tomography of thorax
# 9352:Application of neck support
# 8838:Other computerized axial tomography
# 8703:Computerized axial tomography of head
# 8801:Computerized axial tomography of abdomen
# 8871:Diagnostic ultrasound of head and neck
# 8703:Computerized axial tomography of head
# 8841:Arteriography of cerebral arteries
# 8841:Arteriography of cerebral arteries
# 5425:Peritoneal lavage
# 311:Temporary tracheostomy
# 5472:Other repair of abdominal wall
# 8622:Excisional debridement of wound, infection, or burn
# 5411:Exploratory laparotomy
# 3893:Venous catheterization, not elsewhere classified
# 9356:Application of pressure dressing
# 3324:Closed [endoscopic] biopsy of bronchus
# 5499:Other operations of abdominal region
# 9356:Application of pressure dressing
# 3893:Venous catheterization, not elsewhere classified
# 3491:Thoracentesis
# 9635:Gastric gavage
# 8669:Other skin graft to other sites
# 3893:Venous catheterization, not elsewhere classified
# 3491:Thoracentesis
# 3893:Venous catheterization, not elsewhere classified
# 9356:Application of pressure dressing
# 8669:Other skin graft to other sites
# 0481:Injection of anesthetic into peripheral nerve for analgesia
# 3451:Decortication of lung
# 3409:Other incision of pleura
# 9356:Application of pressure dressing
# 3893:Venous catheterization, not elsewhere classified
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 80702:Fracture two ribs-closed:Closed fracture of two ribs
# 8054:Fx lumbar vertebra-close:Closed fracture of lumbar vertebra without mention of spinal cord injury
# ========== PRS ==========
# 8826:Other skeletal x-ray of pelvis and hip
# 8724:Other x-ray of lumbosacral spine
# 8823:Skeletal x-ray of wrist and hand
# 8801:Computerized axial tomography of abdomen
# 8838:Other computerized axial tomography
# 8741:Computerized axial tomography of thorax
# 8703:Computerized axial tomography of head
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 83501:Posterior disloc hip-cl:Closed posterior dislocation of hip
# 808:Fracture of pelvis:None
# ========== PRS ==========
# 7939:Open reduction of fracture with internal fixation, other specified bone
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 90003:Inj internal carotid art:Injury to internal carotid artery
# 920:Contusion of face, scalp, and neck except eye(s):None
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# 8470:Sprain of neck:Sprain of neck
# 92410:Contusion of lower leg:Contusion of lower leg
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 95911:Injury of chest wall NEC:Other injury of chest wall
# 8485:Sprain of pelvis:Sprain of pelvic
# 8472:Sprain lumbar region:Sprain of lumbar
# 8470:Sprain of neck:Sprain of neck
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9100:Abrasion head:Abrasion or friction burn of face, neck, and scalp except eye, without mention of infection
# 8505:Concussion w coma NOS:Concussion with loss of consciousness of unspecified duration
# 82532:Fx navicular, foot-open:Open fracture of navicular [scaphoid], foot
# 82531:Fx astragalus-open:Open fracture of astragalus
# 49390:Asthma NOS:Asthma, unspecified type, unspecified
# ========== PRS ==========
# 8087:Other local excision or destruction of lesion of joint, ankle
# 7907:Closed reduction of fracture without internal fixation, tarsals and metatarsals
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8472:Sprain lumbar region:Sprain of lumbar
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8509:Concussion NOS:Concussion, unspecified
# 920:Contusion of face, scalp, and neck except eye(s):None
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 86122:Lung laceration-closed:Laceration of lung without mention of open wound into thorax
# 86121:Lung contusion-closed:Contusion of lung without mention of open wound into thorax
# 8670:Bladder/urethra inj-clos:Injury to bladder and urethra, without mention of open wound into cavity
# 8056:Fx sacrum/coccyx-closed:Closed fracture of sacrum and coccyx without mention of spinal cord injury
# 80849:Pelvic fracture NEC-clos:Closed fracture of other specified part of pelvis
# 83942:Dislocat sacrum-closed:Closed dislocation, sacrum
# 83969:Dislocat site NEC-closed:Closed dislocation, other location
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# ========== PRS ==========
# 7919:Closed reduction of fracture with internal fixation, other specified bone
# 7819:Application of external fixator device, other bones
# 5718:Other suprapubic cystostomy
# 5844:Reanastomosis of urethra
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 83803:Disloc tarsometatars-cl:Closed dislocation of tarsometatarsal (joint)
# 8260:Fx phalanx, foot-closed:Closed fracture of one or more phalanges of foot
# 82525:Fx metatarsal-closed:Closed fracture of metatarsal bone(s)
# 82523:Fx cuboid-closed:Closed fracture of cuboid
# 82310:Fx upper end tibia-open:Open fracture of upper end of tibia alone
# 8221:Fracture patella-open:Open fracture of patella
# 82131:Fx femoral condyle-open:Open fracture of condyle, femoral
# 82111:Fx femur shaft-open:Open fracture of shaft of femur
# 81002:Fx clavicle shaft-closed:Closed fracture of shaft of clavicle
# 8054:Fx lumbar vertebra-close:Closed fracture of lumbar vertebra without mention of spinal cord injury
# ========== PRS ==========
# 8828:Skeletal x-ray of ankle and foot
# 8828:Skeletal x-ray of ankle and foot
# 5794:Insertion of indwelling urinary catheter
# 8826:Other skeletal x-ray of pelvis and hip
# 8827:Skeletal x-ray of thigh, knee, and lower leg
# 8827:Skeletal x-ray of thigh, knee, and lower leg
# 8838:Other computerized axial tomography
# 8744:Routine chest x-ray, so described
# 8742:Other tomography of thorax
# 8801:Computerized axial tomography of abdomen
# 8703:Computerized axial tomography of head
# 8704:Other tomography of head
# 8952:Electrocardiogram
# 7817:Application of external fixator device, tibia and fibula
# 7815:Application of external fixator device, femur
# 8659:Closure of skin and subcutaneous tissue of other sites
# 7966:Debridement of open fracture site, tibia and fibula
# 7937:Open reduction of fracture with internal fixation, tarsals and metatarsals
# 7965:Debridement of open fracture site, femur
# 3893:Venous catheterization, not elsewhere classified
# 7939:Open reduction of fracture with internal fixation, other specified bone
# 8622:Excisional debridement of wound, infection, or burn
# 7936:Open reduction of fracture with internal fixation, tibia and fibula
# 8345:Other myectomy
# 8455:Insertion of bone void filler
# 7935:Open reduction of fracture with internal fixation, femur
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 85011:Concus-brief coma <31 mn:Concussion, with loss of consciousness of 30 minutes or less
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8509:Concussion NOS:Concussion, unspecified
# ========== PRS ==========
# 9352:Application of neck support
# 9634:Other irrigation of (naso-)gastric tube
# 5794:Insertion of indwelling urinary catheter
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 920:Contusion of face, scalp, and neck except eye(s):None
# 85206:Subarach hem-coma NOS:Subarachnoid hemorrhage following injury without mention of open intracranial wound, with loss of consciousness of unspecified duration
# 8505:Concussion w coma NOS:Concussion with loss of consciousness of unspecified duration
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# 90239:Inj port/splen vess NEC:Injury to portal and splenic veins, other
# 86389:GI injury NEC-closed:Injury to other gastrointestinal sites, without mention of open wound into cavity
# 8082:Fracture of pubis-closed:Closed fracture of pubis
# 80703:Fracture three ribs-clos:Closed fracture of three ribs
# 8056:Fx sacrum/coccyx-closed:Closed fracture of sacrum and coccyx without mention of spinal cord injury
# 8054:Fx lumbar vertebra-close:Closed fracture of lumbar vertebra without mention of spinal cord injury
# ========== PRS ==========
# 5411:Exploratory laparotomy
# 5475:Other repair of mesentery
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8054:Fx lumbar vertebra-close:Closed fracture of lumbar vertebra without mention of spinal cord injury
# 86601:Kidney hematoma-closed:Injury to kidney without mention of open wound into cavity, hematoma without rupture of capsule
# 8056:Fx sacrum/coccyx-closed:Closed fracture of sacrum and coccyx without mention of spinal cord injury
# 80701:Fracture one rib-closed:Closed fracture of one rib
# 8082:Fracture of pubis-closed:Closed fracture of pubis
# ========== PRS ==========
# 3893:Venous catheterization, not elsewhere classified
# 8952:Electrocardiogram
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8470:Sprain of neck:Sprain of neck
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9588:Early complic trauma NEC:Other early complications of trauma
# ========== PRS ==========
# 8893:Magnetic resonance imaging of spinal canal
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# 8801:Computerized axial tomography of abdomen
# 8659:Closure of skin and subcutaneous tissue of other sites
# 8703:Computerized axial tomography of head
# 9352:Application of neck support
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 86121:Lung contusion-closed:Contusion of lung without mention of open wound into thorax
# 86502:Spleen capsular tear:Injury to spleen without mention of open wound into cavity, capsular tears, without major disruption of parenchyma
# 80701:Fracture one rib-closed:Closed fracture of one rib
# 9222:Contusion abdominal wall:Contusion of abdominal wall
# 82380:Fx tibia NOS-closed:Closed fracture of unspecified part of tibia alone
# ========== PRS ==========
# 5794:Insertion of indwelling urinary catheter
# 3893:Venous catheterization, not elsewhere classified
# 9604:Insertion of endotracheal tube
# 9671:Continuous invasive mechanical ventilation for less than 96 consecutive hours
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 87340:Open wound of face NOS:Open wound of face, unspecified site, without mention of complication
# 83500:Dislocat hip NOS-closed:Closed dislocation of hip, unspecified site
# 81500:Fx metacarpal NOS-closed:Closed fracture of metacarpal bone(s), site unspecified
# 80841:Fracture of ilium-closed:Closed fracture of ilium
# 8080:Fracture acetabulum-clos:Closed fracture of acetabulum
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9248:Multiple contusions NEC:Contusion of multiple sites, not elsewhere classified
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# 8509:Concussion NOS:Concussion, unspecified
# ========== PRS ==========
# 8703:Computerized axial tomography of head
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 850:Concussion:None
# 822:Fracture of patella:None
# 80708:Fx eight/more rib-closed:Closed fracture of eight or more ribs
# ========== PRS ==========
# 8703:Computerized axial tomography of head
# 8722:Other x-ray of cervical spine
# 8801:Computerized axial tomography of abdomen
# 8741:Computerized axial tomography of thorax
# 7936:Open reduction of fracture with internal fixation, tibia and fibula
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8072:Fracture of sternum-clos:Closed fracture of sternum
# 80705:Fracture five ribs-close:Closed fracture of five ribs
# ========== PRS ==========
# 8741:Computerized axial tomography of thorax
# 9919:Injection of anticoagulant
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9245:Contusion leg NOS:Contusion of unspecified part of lower limb
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 8160:Closed fracture of one or more phalanges of hand:None
# 81341:Colles' fracture-closed:Closed Colles' fracture
# 80701:Fracture one rib-closed:Closed fracture of one rib
# ========== PRS ==========
# 7912:Closed reduction of fracture with internal fixation, radius and ulna
# 7914:Closed reduction of fracture with internal fixation, phalanges of hand
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 82322:Fx shaft fib w tib-clos:Closed fracture of shaft of fibula with tibia
# ========== PRS ==========
# 8703:Computerized axial tomography of head
# 8801:Computerized axial tomography of abdomen
# 8838:Other computerized axial tomography
# 7906:Closed reduction of fracture without internal fixation, tibia and fibula
# 0481:Injection of anesthetic into peripheral nerve for analgesia
# 7936:Open reduction of fracture with internal fixation, tibia and fibula
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# 9120:Abrasion shoulder/arm:Abrasion or friction burn of shoulder and upper arm, without mention of infection
# 8730:Open wound of scalp:Open wound of scalp, without mention of complication
# 82022:Subtrochanteric fx-close:Closed fracture of subtrochanteric section of neck of femur
# 80506:Fx c6 vertebra-closed:Closed fracture of sixth cervical vertebra
# ========== PRS ==========
# 8628:Nonexcisional debridement of wound, infection or burn
# 8659:Closure of skin and subcutaneous tissue of other sites
# 9659:Other irrigation of wound
# 8741:Computerized axial tomography of thorax
# 9344:Other skeletal traction
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# 9354:Application of splint
# 8801:Computerized axial tomography of abdomen
# 8703:Computerized axial tomography of head
# 7935:Open reduction of fracture with internal fixation, femur
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 87361:Open wound buccal mucosa:Open wound of buccal mucosa, without mention of complication
# 87352:Open wnd forehead-compl:Open wound of forehead, complicated
# 81400:Fx carpal bone NOS-close:Closed fracture of carpal bone, unspecified
# 81344:Fx low radius w ulna-cl:Closed fracture of lower end of radius with ulna
# ========== PRS ==========
# 7902:Closed reduction of fracture without internal fixation, radius and ulna
# 8659:Closure of skin and subcutaneous tissue of other sites
# 0881:Linear repair of laceration of eyelid or eyebrow
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 80704:Fracture four ribs-close:Closed fracture of four ribs
# ========== PRS ==========
# 8838:Other computerized axial tomography
# 8703:Computerized axial tomography of head
# 8801:Computerized axial tomography of abdomen
# 8741:Computerized axial tomography of thorax
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8470:Sprain of neck:Sprain of neck
# 8472:Sprain lumbar region:Sprain of lumbar
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 95909:Face & neck injury:Injury of face and neck
# 9110:Abrasion trunk:Abrasion or friction burn of trunk, without mention of infection
# 8798:Open wound site NOS:Open wound(s) (multiple) of unspecified site(s), without mention of complication
# 86403:Liver laceration, mod:Injury to liver without mention of open wound into cavity, laceration, moderate
# 8370:Dislocation ankle-closed:Closed dislocation of ankle
# 83501:Posterior disloc hip-cl:Closed posterior dislocation of hip
# 82521:Fx astragalus-closed:Closed fracture of astragalus
# 8250:Fracture calcaneus-close:Fracture of calcaneus, closed
# 82101:Fx femur shaft-closed:Closed fracture of shaft of femur
# 81221:Fx humerus shaft-closed:Closed fracture of shaft of humerus
# 8080:Fracture acetabulum-clos:Closed fracture of acetabulum
# 8028:Fx facial bone NEC-close:Closed fracture of other facial bones
# 8024:Fx malar/maxillary-close:Closed fracture of malar and maxillary bones
# ========== PRS ==========
# 7985:Open reduction of dislocation of hip
# 7905:Closed reduction of fracture without internal fixation, femur
# 8471:Application of external fixator device, monoplanar system
# 7815:Application of external fixator device, femur
# 7915:Closed reduction of fracture with internal fixation, femur
# 7905:Closed reduction of fracture without internal fixation, femur
# 7718:Other incision of bone without division, tarsals and metatarsals
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9248:Multiple contusions NEC:Contusion of multiple sites, not elsewhere classified
# 920:Contusion of face, scalp, and neck except eye(s):None
# 8900:Open wound of hip/thigh:Open wound of hip and thigh, without mention of complication
# 8509:Concussion NOS:Concussion, unspecified
# 8472:Sprain lumbar region:Sprain of lumbar
# ========== PRS ==========
# 8659:Closure of skin and subcutaneous tissue of other sites
# 8703:Computerized axial tomography of head
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 86121:Lung contusion-closed:Contusion of lung without mention of open wound into thorax
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 8250:Fracture calcaneus-close:Fracture of calcaneus, closed
# 8220:Fracture patella-closed:Closed fracture of patella
# 82101:Fx femur shaft-closed:Closed fracture of shaft of femur
# 8080:Fracture acetabulum-clos:Closed fracture of acetabulum
# 80701:Fracture one rib-closed:Closed fracture of one rib
# 80507:Fx c7 vertebra-closed:Closed fracture of seventh cervical vertebra
# ========== PRS ==========
# 8801:Computerized axial tomography of abdomen
# 8703:Computerized axial tomography of head
# 8838:Other computerized axial tomography
# 793:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 85300:Traumatic brain hem NEC:Other and unspecified intracranial hemorrhage following injury without mention of open intracranial wound, unspecified state of consciousness
# 9100:Abrasion head:Abrasion or friction burn of face, neck, and scalp except eye, without mention of infection
# 86121:Lung contusion-closed:Contusion of lung without mention of open wound into thorax
# 8074:Flail chest:Flail chest
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 86802:Biliary tract injury-cl:Injury to other intra-abdominal organs without mention of open wound into cavity, bile duct and gallbladder
# 8240:Fx medial malleolus-clos:Fracture of medial malleolus, closed
# 8242:Fx lateral malleolus-cl:Fracture of lateral malleolus, closed
# 82521:Fx astragalus-closed:Closed fracture of astragalus
# 8250:Fracture calcaneus-close:Fracture of calcaneus, closed
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# ========== PRS ==========
# 5411:Exploratory laparotomy
# 5412:Reopening of recent laparotomy site
# 3129:Other permanent tracheostomy
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8505:Concussion w coma NOS:Concussion with loss of consciousness of unspecified duration
# ========== PRS ==========
# 8703:Computerized axial tomography of head
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9521:Dorsal (thoracic) spinal cord injury without evidence of spinal bone injury:None
# 9248:Multiple contusions NEC:Contusion of multiple sites, not elsewhere classified
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# 8509:Concussion NOS:Concussion, unspecified
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9222:Contusion abdominal wall:Contusion of abdominal wall
# 9110:Abrasion trunk:Abrasion or friction burn of trunk, without mention of infection
# 9100:Abrasion head:Abrasion or friction burn of face, neck, and scalp except eye, without mention of infection
# 86804:Retroperitoneum inj-cl:Injury to other intra-abdominal organs without mention of open wound into cavity, retroperitoneum
# 86121:Lung contusion-closed:Contusion of lung without mention of open wound into thorax
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 82529:Fx foot bone NEC-closed:Other closed fracture of tarsal and metatarsal bones
# 82523:Fx cuboid-closed:Closed fracture of cuboid
# 82521:Fx astragalus-closed:Closed fracture of astragalus
# 8250:Fracture calcaneus-close:Fracture of calcaneus, closed
# 8248:Fx ankle NOS-closed:Unspecified fracture of ankle, closed
# 8232:Fracture of shaft of tibia and fibula closed:None
# 8080:Fracture acetabulum-clos:Closed fracture of acetabulum
# 8072:Fracture of sternum-clos:Closed fracture of sternum
# 80709:Fx mult ribs NOS-closed:Closed fracture of multiple ribs, unspecified
# 8052:Fx dorsal vertebra-close:Closed fracture of dorsal [thoracic] vertebra without mention of spinal cord injury
# 80502:Fx c2 vertebra-closed:Closed fracture of second cervical vertebra
# ========== PRS ==========
# 9604:Insertion of endotracheal tube
# 9354:Application of splint
# 9671:Continuous invasive mechanical ventilation for less than 96 consecutive hours
# 7906:Closed reduction of fracture without internal fixation, tibia and fibula
# 7937:Open reduction of fracture with internal fixation, tarsals and metatarsals
# 8314:Fasciotomy
# 7817:Application of external fixator device, tibia and fibula
# 3404:Insertion of intercostal catheter for drainage
# 7867:Removal of implanted devices from bone, tibia and fibula
# 8339:Excision of lesion of other soft tissue
# 387:Interruption of the vena cava
# 8851:Angiocardiography of venae cavae
# 7936:Open reduction of fracture with internal fixation, tibia and fibula
# 7937:Open reduction of fracture with internal fixation, tarsals and metatarsals
# 8415:Other amputation below knee
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 86413:Liver lacerat, mod-open:Injury to liver with open wound into cavity, laceration, moderate
# 86121:Lung contusion-closed:Contusion of lung without mention of open wound into thorax
# 80709:Fx mult ribs NOS-closed:Closed fracture of multiple ribs, unspecified
# 8054:Fx lumbar vertebra-close:Closed fracture of lumbar vertebra without mention of spinal cord injury
# ========== PRS ==========
# 9335:Other heat therapy
# 8703:Computerized axial tomography of head
# 8838:Other computerized axial tomography
# 8838:Other computerized axial tomography
# 8741:Computerized axial tomography of thorax
# 8801:Computerized axial tomography of abdomen
# 8744:Routine chest x-ray, so described
# 8838:Other computerized axial tomography
# 8826:Other skeletal x-ray of pelvis and hip
# 8879:Other diagnostic ultrasound
# 8801:Computerized axial tomography of abdomen
# 8952:Electrocardiogram
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9239:Contusion upper limb NOS:Contusion of unspecified part of upper limb
# 9130:Abrasion forearm:Abrasion or friction burn of elbow, forearm, and wrist, without mention of infection
# 9100:Abrasion head:Abrasion or friction burn of face, neck, and scalp except eye, without mention of infection
# 85220:Traumatic subdural hem:Subdural hemorrhage following injury without mention of open intracranial wound, unspecified state of consciousness
# ========== PRS ==========
# 9938:Administration of tetanus toxoid
# 8838:Other computerized axial tomography
# 8703:Computerized axial tomography of head
# 8801:Computerized axial tomography of abdomen
# 8741:Computerized axial tomography of thorax
# 9359:Other immobilization, pressure, and attention to wound
# 8877:Diagnostic ultrasound of peripheral vascular system
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 920:Contusion of face, scalp, and neck except eye(s):None
# 9120:Abrasion shoulder/arm:Abrasion or friction burn of shoulder and upper arm, without mention of infection
# 8470:Sprain of neck:Sprain of neck
# 80709:Fx mult ribs NOS-closed:Closed fracture of multiple ribs, unspecified
# ========== PRS ==========
# <UNK>:Unknown Code
# <UNK>:Unknown Code
# <UNK>:Unknown Code
# <UNK>:Unknown Code
# <UNK>:Unknown Code
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9245:Contusion leg NOS:Contusion of unspecified part of lower limb
# 86601:Kidney hematoma-closed:Injury to kidney without mention of open wound into cavity, hematoma without rupture of capsule
# 86502:Spleen capsular tear:Injury to spleen without mention of open wound into cavity, capsular tears, without major disruption of parenchyma
# 80841:Fracture of ilium-closed:Closed fracture of ilium
# 8082:Fracture of pubis-closed:Closed fracture of pubis
# 8080:Fracture acetabulum-clos:Closed fracture of acetabulum
# ========== PRS ==========
# 8741:Computerized axial tomography of thorax
# 8801:Computerized axial tomography of abdomen
# 8838:Other computerized axial tomography
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# 8703:Computerized axial tomography of head
# 884:Unknown Code
# 3979:Other endovascular procedures on other vessels
# 9215:Pulmonary scan
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# 9160:Abrasion hip & leg:Abrasion or friction burn of hip, thigh, leg, and ankle, without mention of infection
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 83500:Dislocat hip NOS-closed:Closed dislocation of hip, unspecified site
# 82021:Intertrochanteric fx-cl:Closed fracture of intertrochanteric section of neck of femur
# 81322:Fx ulna shaft-closed:Closed fracture of shaft of ulna (alone)
# 8080:Fracture acetabulum-clos:Closed fracture of acetabulum
# 80707:Fracture seven ribs-clos:Closed fracture of seven ribs
# 8054:Fx lumbar vertebra-close:Closed fracture of lumbar vertebra without mention of spinal cord injury
# 80507:Fx c7 vertebra-closed:Closed fracture of seventh cervical vertebra
# 80506:Fx c6 vertebra-closed:Closed fracture of sixth cervical vertebra
# 80505:Fx c5 vertebra-closed:Closed fracture of fifth cervical vertebra
# ========== PRS ==========
# 8744:Routine chest x-ray, so described
# 8826:Other skeletal x-ray of pelvis and hip
# 9918:Injection or infusion of electrolytes
# 8822:Skeletal x-ray of elbow and forearm
# 8821:Skeletal x-ray of shoulder and upper arm
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# 8823:Skeletal x-ray of wrist and hand
# 8872:Diagnostic ultrasound of heart
# 8838:Other computerized axial tomography
# 5794:Insertion of indwelling urinary catheter
# 9352:Application of neck support
# 8838:Other computerized axial tomography
# 8801:Computerized axial tomography of abdomen
# 8844:Arteriography of other intrathoracic vessels
# 8703:Computerized axial tomography of head
# 8838:Other computerized axial tomography
# 8744:Routine chest x-ray, so described
# 9918:Injection or infusion of electrolytes
# 8828:Skeletal x-ray of ankle and foot
# 8829:Skeletal x-ray of lower limb, not otherwise specified
# 8838:Other computerized axial tomography
# 8838:Other computerized axial tomography
# 8841:Arteriography of cerebral arteries
# 8151:Total hip replacement
# 7939:Open reduction of fracture with internal fixation, other specified bone
# 7932:Open reduction of fracture with internal fixation, radius and ulna
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8080:Fracture acetabulum-clos:Closed fracture of acetabulum
# 8028:Fx facial bone NEC-close:Closed fracture of other facial bones
# 8026:Fx orbital floor-closed:Closed fracture of orbital floor (blow-out)
# 8020:Nasal bone fx-closed:Closed fracture of nasal bones
# ========== PRS ==========
# 8659:Closure of skin and subcutaneous tissue of other sites
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8470:Sprain of neck:Sprain of neck
# 86402:Liver laceration, minor:Injury to liver without mention of open wound into cavity, laceration, minor
# 86602:Kidney laceration-closed:Injury to kidney without mention of open wound into cavity, laceration
# 8054:Fx lumbar vertebra-close:Closed fracture of lumbar vertebra without mention of spinal cord injury
# 8056:Fx sacrum/coccyx-closed:Closed fracture of sacrum and coccyx without mention of spinal cord injury
# 82321:Fx shaft fibula-closed:Closed fracture of shaft of fibula alone
# 8910:Open wnd knee/leg/ankle:Open wound of knee, leg [except thigh], and ankle, without mention of complication
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 85402:Brain inj NEC-brief coma:Intracranial injury of other and unspecified nature without mention of open intracranial wound, with brief [less than one hour] loss of consciousness
# 920:Contusion of face, scalp, and neck except eye(s):None
# 87341:Open wound of cheek:Open wound of cheek, without mention of complication
# 8054:Fx lumbar vertebra-close:Closed fracture of lumbar vertebra without mention of spinal cord injury
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 8246:Fx trimalleolar-closed:Trimalleolar fracture, closed
# 82381:Fx fibula NOS-closed:Closed fracture of unspecified part of fibula alone
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# ========== PRS ==========
# 7817:Application of external fixator device, tibia and fibula
# 7906:Closed reduction of fracture without internal fixation, tibia and fibula
# 7936:Open reduction of fracture with internal fixation, tibia and fibula
# 8839:X-ray, other and unspecified
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 95911:Injury of chest wall NEC:Other injury of chest wall
# 9120:Abrasion shoulder/arm:Abrasion or friction burn of shoulder and upper arm, without mention of infection
# 8470:Sprain of neck:Sprain of neck
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 87342:Open wound of forehead:Open wound of forehead, without mention of complication
# 86502:Spleen capsular tear:Injury to spleen without mention of open wound into cavity, capsular tears, without major disruption of parenchyma
# 86121:Lung contusion-closed:Contusion of lung without mention of open wound into thorax
# 85400:Brain injury NEC:Intracranial injury of other and unspecified nature without mention of open intracranial wound, unspecified state of consciousness
# 80709:Fx mult ribs NOS-closed:Closed fracture of multiple ribs, unspecified
# 8054:Fx lumbar vertebra-close:Closed fracture of lumbar vertebra without mention of spinal cord injury
# 8052:Fx dorsal vertebra-close:Closed fracture of dorsal [thoracic] vertebra without mention of spinal cord injury
# 80507:Fx c7 vertebra-closed:Closed fracture of seventh cervical vertebra
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9110:Abrasion trunk:Abrasion or friction burn of trunk, without mention of infection
# 86802:Biliary tract injury-cl:Injury to other intra-abdominal organs without mention of open wound into cavity, bile duct and gallbladder
# 86389:GI injury NEC-closed:Injury to other gastrointestinal sites, without mention of open wound into cavity
# 86381:Pancreas, head inj-close:Injury to pancreas, head, without mention of open wound into cavity
# 8230:Fracture of upper end of tibia and fibula closed:None
# 82101:Fx femur shaft-closed:Closed fracture of shaft of femur
# 8208:Fx neck of femur NOS-cl:Closed fracture of unspecified part of neck of femur
# 8070:Closed fracture of rib(s):None
# ========== PRS ==========
# 5122:Cholecystectomy
# 5475:Other repair of mesentery
# 5209:Other pancreatotomy
# 7855:Internal fixation of bone without fracture reduction, femur
# 9671:Continuous invasive mechanical ventilation for less than 96 consecutive hours
# 9604:Insertion of endotracheal tube
# 7917:Closed reduction of fracture with internal fixation, tarsals and metatarsals
# 7936:Open reduction of fracture with internal fixation, tibia and fibula
# 7807:Bone graft, tibia and fibula
# 7937:Open reduction of fracture with internal fixation, tarsals and metatarsals
# 8385:Other change in muscle or tendon length
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 80704:Fracture four ribs-close:Closed fracture of four ribs
# ========== PRS ==========
# 3404:Insertion of intercostal catheter for drainage
# 9604:Insertion of endotracheal tube
# 3891:Arterial catheterization
# 3893:Venous catheterization, not elsewhere classified
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 85220:Traumatic subdural hem:Subdural hemorrhage following injury without mention of open intracranial wound, unspecified state of consciousness
# ========== PRS ==========
# 9604:Insertion of endotracheal tube
# 8964:Pulmonary artery wedge monitoring
# 3893:Venous catheterization, not elsewhere classified
# 3891:Arterial catheterization
# 966:Enteral infusion of concentrated nutritional substances
# 3322:Fiber-optic bronchoscopy
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 95901:Head injury NOS:Head injury, unspecified
# 80502:Fx c2 vertebra-closed:Closed fracture of second cervical vertebra
# ========== PRS ==========
# 8703:Computerized axial tomography of head
# 8741:Computerized axial tomography of thorax
# 8801:Computerized axial tomography of abdomen
# 9918:Injection or infusion of electrolytes
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9221:Contusion of chest wall:Contusion of chest wall
# 8249:Fx ankle NOS-open:Unspecified fracture of ankle, open
# ========== PRS ==========
# 7936:Open reduction of fracture with internal fixation, tibia and fibula
# 8659:Closure of skin and subcutaneous tissue of other sites
# 7966:Debridement of open fracture site, tibia and fibula
# 7817:Application of external fixator device, tibia and fibula
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9244:Multiple contusion leg:Contusion of multiple sites of lower limb
# 92311:Contusion of elbow:Contusion of elbow
# 8830:Open wound of finger:Open wound of finger(s), without mention of complication
# 8243:Fx lateral malleolus-opn:Fracture of lateral malleolus, open
# 82390:Fx tibia NOS-open:Open fracture of unspecified part of tibia alone
# ========== PRS ==========
# 7817:Application of external fixator device, tibia and fibula
# 7906:Closed reduction of fracture without internal fixation, tibia and fibula
# 7936:Open reduction of fracture with internal fixation, tibia and fibula
# 7936:Open reduction of fracture with internal fixation, tibia and fibula
# 7817:Application of external fixator device, tibia and fibula
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9248:Multiple contusions NEC:Contusion of multiple sites, not elsewhere classified
# 86502:Spleen capsular tear:Injury to spleen without mention of open wound into cavity, capsular tears, without major disruption of parenchyma
# 8604:Traum pneumohemothor-cl:Traumatic pneumohemothorax without mention of open wound into thorax
# 80701:Fracture one rib-closed:Closed fracture of one rib
# 8052:Fx dorsal vertebra-close:Closed fracture of dorsal [thoracic] vertebra without mention of spinal cord injury
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# 8509:Concussion NOS:Concussion, unspecified
# ========== PRS ==========
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# 8703:Computerized axial tomography of head
# 8838:Other computerized axial tomography
# 8839:X-ray, other and unspecified
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 86403:Liver laceration, mod:Injury to liver without mention of open wound into cavity, laceration, moderate
# 82525:Fx metatarsal-closed:Closed fracture of metatarsal bone(s)
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8472:Sprain lumbar region:Sprain of lumbar
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 87342:Open wound of forehead:Open wound of forehead, without mention of complication
# 8449:Sprain of knee & leg NOS:Sprains and strains of unspecified site of knee and leg
# 8052:Fx dorsal vertebra-close:Closed fracture of dorsal [thoracic] vertebra without mention of spinal cord injury
# ========== PRS ==========
# 8801:Computerized axial tomography of abdomen
# 8771:Computerized axial tomography of kidney
# ...
# 82525:Fx metatarsal-closed:Closed fracture of metatarsal bone(s)
# 82522:Fx navicular, foot-clos:Closed fracture of navicular [scaphoid], foot
# 8920:Open wound of foot:Open wound of foot except toe(s) alone, without mention of complication
# 9974:Digestive system complications not elsewhere classified:None
# 5601:Paralytic ileus:Paralytic ileus
# 78009:Other alter consciousnes:Other alteration of consciousness
# 6202:Ovarian cyst NEC/NOS:Other and unspecified ovarian cyst
# ========== PRS ==========
# 7907:Closed reduction of fracture without internal fixation, tarsals and metatarsals
# 5411:Exploratory laparotomy
# 4561:Multiple segmental resection of small intestine
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9222:Contusion abdominal wall:Contusion of abdominal wall
# 9221:Contusion of chest wall:Contusion of chest wall
# 920:Contusion of face, scalp, and neck except eye(s):None
# 85201:Subarachnoid hem-no coma:Subarachnoid hemorrhage following injury without mention of open intracranial wound, with no loss of consciousness
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9248:Multiple contusions NEC:Contusion of multiple sites, not elsewhere classified
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# 86503:Spleen parenchyma lacer:Injury to spleen without mention of open wound into cavity, laceration extending into parenchyma
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 81209:Fx upper humerus NEC-cl:Other closed fracture of upper end of humerus
# 81202:Fx anatom nck humerus-cl:Closed fracture of anatomical neck of humerus
# 81109:Fx scapula NEC-closed:Closed fracture of scapula, other
# 81002:Fx clavicle shaft-closed:Closed fracture of shaft of clavicle
# 8072:Fracture of sternum-clos:Closed fracture of sternum
# 80709:Fx mult ribs NOS-closed:Closed fracture of multiple ribs, unspecified
# 80501:Fx c1 vertebra-closed:Closed fracture of first cervical vertebra
# 8028:Fx facial bone NEC-close:Closed fracture of other facial bones
# 8024:Fx malar/maxillary-close:Closed fracture of malar and maxillary bones
# 80025:Cl skul vlt fx-deep coma:Closed fracture of vault of skull with subarachnoid, subdural, and extradural hemorrhage, with prolonged [more than 24 hours] loss of consciousness, without return to pre-existing conscious level
# ========== PRS ==========
# 8703:Computerized axial tomography of head
# 9604:Insertion of endotracheal tube
# 9672:Continuous invasive mechanical ventilation for 96 consecutive hours or more
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# 8628:Nonexcisional debridement of wound, infection or burn
# 8699:Other operations on skin and subcutaneous tissue
# 8689:Other repair and reconstruction of skin and subcutaneous tissue
# 8659:Closure of skin and subcutaneous tissue of other sites
# 9904:Transfusion of packed cells
# 3893:Venous catheterization, not elsewhere classified
# 3891:Arterial catheterization
# 3886:Other surgical occlusion of vessels, abdominal arteries
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# None
# 9190:Abrasion NEC:Abrasion or friction burn of other, multiple, and unspecified sites, without mention of infection
# 9100:Abrasion head:Abrasion or friction burn of face, neck, and scalp except eye, without mention of infection
# 8054:Fx lumbar vertebra-close:Closed fracture of lumbar vertebra without mention of spinal cord injury
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8479:Sprain of back NOS:Sprain of unspecified site of back
# ========== PRS ==========
# 9352:Application of neck support
# 8744:Routine chest x-ray, so described
# 8801:Computerized axial tomography of abdomen
# 8703:Computerized axial tomography of head
# 8838:Other computerized axial tomography
# 8722:Other x-ray of cervical spine
# 8827:Skeletal x-ray of thigh, knee, and lower leg
# 8741:Computerized axial tomography of thorax
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8841:Open wound arm NOS-compl:Multiple and unspecified open wound of upper limb, complicated
# 8734:Open wound of face without mention of complication:None
# 8612:Lung injury without mention of open wound into thorax:None
# 853:Other and unspecified intracranial hemorrhage following injury:None
# 8249:Fx ankle NOS-open:Unspecified fracture of ankle, open
# 82381:Fx fibula NOS-closed:Closed fracture of unspecified part of fibula alone
# 8233:Fracture of shaft of tibia and fibula open:None
# 8082:Fracture of pubis-closed:Closed fracture of pubis
# 80704:Fracture four ribs-close:Closed fracture of four ribs
# 8024:Fx malar/maxillary-close:Closed fracture of malar and maxillary bones
# 80228:Fx mandible body NEC-cl:Closed fracture of mandible, body, other and unspecified
# 51881:Acute respiratry failure:Acute respiratory failure
# 507:Pneumonitis due to solids and liquids:None
# 48282:Pneumonia e coli:Pneumonia due to escherichia coli [E. coli]
# 4821:Pseudomonal pneumonia:Pneumonia due to Pseudomonas
# 4329:Intracranial hemorr NOS:Unspecified intracranial hemorrhage
# 2851:Ac posthemorrhag anemia:Acute posthemorrhagic anemia
# 280:Iron deficiency anemias:None
# 2768:Hypopotassemia:Hypopotassemia
# 2763:Alkalosis:Alkalosis
# 2753:Dis phosphorus metabol:Disorders of phosphorus metabolism
# 2639:Protein-cal malnutr NOS:Unspecified protein-calorie malnutrition
# ========== PRS ==========
# 011:Unknown Code
# 8961:Systemic arterial pressure monitoring
# 5794:Insertion of indwelling urinary catheter
# 9672:Continuous invasive mechanical ventilation for 96 consecutive hours or more
# 9607:Insertion of other (naso-)gastric tube
# 9939:Administration of diphtheria-tetanus-pertussis, combined
# 9904:Transfusion of packed cells
# 7817:Application of external fixator device, tibia and fibula
# 311:Temporary tracheostomy
# 4432:Percutaneous [endoscopic] gastrojejunostomy
# 4311:Percutaneous [endoscopic] gastrostomy [PEG]
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 92300:Contusion shoulder reg:Contusion of shoulder region
# 85402:Brain inj NEC-brief coma:Intracranial injury of other and unspecified nature without mention of open intracranial wound, with brief [less than one hour] loss of consciousness
# 82301:Fx upper end fibula-clos:Closed fracture of upper end of fibula alone
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8080:Fracture acetabulum-clos:Closed fracture of acetabulum
# ========== PRS ==========
# 8801:Computerized axial tomography of abdomen
# 9396:Other oxygen enrichment
# 8838:Other computerized axial tomography
# 8951:Rhythm electrocardiogram
# 9929:Injection or infusion of other therapeutic or prophylactic substance
# 8703:Computerized axial tomography of head
# 9352:Application of neck support
# 8741:Computerized axial tomography of thorax
# 7905:Closed reduction of fracture without internal fixation, femur
# 7935:Open reduction of fracture with internal fixation, femur
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8604:Traum pneumohemothor-cl:Traumatic pneumohemothorax without mention of open wound into thorax
# 8471:Sprain thoracic region:Sprain of thoracic
# 80703:Fracture three ribs-clos:Closed fracture of three ribs
# ========== PRS ==========
# 3404:Insertion of intercostal catheter for drainage
# 3491:Thoracentesis
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 82101:Fx femur shaft-closed:Closed fracture of shaft of femur
# 53081:Esophageal reflux:Esophageal reflux
# 42613:Av block-2nd degree NEC:Other second degree atrioventricular block
# ========== PRS ==========
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# 8801:Computerized axial tomography of abdomen
# 8838:Other computerized axial tomography
# 7935:Open reduction of fracture with internal fixation, femur
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9160:Abrasion hip & leg:Abrasion or friction burn of hip, thigh, leg, and ankle, without mention of infection
# 8840:Open wound arm mult/NOS:Multiple and unspecified open wound of upper limb, without mention of complication
# 8470:Sprain of neck:Sprain of neck
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 85011:Concus-brief coma <31 mn:Concussion, with loss of consciousness of 30 minutes or less
# ========== PRS ==========
# 8838:Other computerized axial tomography
# 8703:Computerized axial tomography of head
# 8801:Computerized axial tomography of abdomen
# 8741:Computerized axial tomography of thorax
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 95901:Head injury NOS:Head injury, unspecified
# 8460:Sprain lumbosacral:Sprain of lumbosacral (joint) (ligament)
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8910:Open wnd knee/leg/ankle:Open wound of knee, leg [except thigh], and ankle, without mention of complication
# 85306:Brain hem NEC-coma NOS:Other and unspecified intracranial hemorrhage following injury without mention of open intracranial wound, with loss of consciousness of unspecified duration
# 85206:Subarach hem-coma NOS:Subarachnoid hemorrhage following injury without mention of open intracranial wound, with loss of consciousness of unspecified duration
# 85106:Cortex contus-coma NOS:Cortex (cerebral) contusion without mention of open intracranial wound, with loss of consciousness of unspecified duration
# ========== PRS ==========
# 966:Enteral infusion of concentrated nutritional substances
# 5794:Insertion of indwelling urinary catheter
# 9604:Insertion of endotracheal tube
# 9918:Injection or infusion of electrolytes
# 8838:Other computerized axial tomography
# 8801:Computerized axial tomography of abdomen
# 8741:Computerized axial tomography of thorax
# 8703:Computerized axial tomography of head
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 82322:Fx shaft fib w tib-clos:Closed fracture of shaft of fibula with tibia
# ========== PRS ==========
# 7936:Open reduction of fracture with internal fixation, tibia and fibula
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 9591:Other and unspecified injury to trunk:None
# 92311:Contusion of elbow:Contusion of elbow
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 920:Contusion of face, scalp, and neck except eye(s):None
# 8730:Open wound of scalp:Open wound of scalp, without mention of complication
# 86122:Lung laceration-closed:Laceration of lung without mention of open wound into thorax
# 82300:Fx upper end tibia-close:Closed fracture of upper end of tibia alone
# 82123:Supracondyl fx femur-cl:Closed supracondylar fracture of femur
# 82101:Fx femur shaft-closed:Closed fracture of shaft of femur
# 82021:Intertrochanteric fx-cl:Closed fracture of intertrochanteric section of neck of femur
# 8054:Fx lumbar vertebra-close:Closed fracture of lumbar vertebra without mention of spinal cord injury
# 80500:Fx cervical vert NOS-cl:Closed fracture of cervical vertebra, unspecified level
# 71906:Joint effusion-l/leg:Effusion of joint, lower leg
# 3453:Grand mal status:Grand mal status
# 28261:Hb-SS disease w/o crisis:Hb-SS disease without crisis
# ========== PRS ==========
# 7935:Open reduction of fracture with internal fixation, femur
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 910:Superficial injury of face neck and scalp except eye:None
# 8509:Concussion NOS:Concussion, unspecified
# ========== PRS ==========
# 8838:Other computerized axial tomography
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# 8741:Computerized axial tomography of thorax
# 8801:Computerized axial tomography of abdomen
# 8703:Computerized axial tomography of head
# 8893:Magnetic resonance imaging of spinal canal
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8470:Sprain of neck:Sprain of neck
# ========== PRS ==========
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8760:Open wound of back:Open wound of back, without mention of complication
# 8734:Open wound of face without mention of complication:None
# 8520:Subarachnoid hemorrhage following injury without mention of open intracranial wound:None
# 8509:Concussion NOS:Concussion, unspecified
# 80502:Fx c2 vertebra-closed:Closed fracture of second cervical vertebra
# ========== PRS ==========
# 8659:Closure of skin and subcutaneous tissue of other sites
# 8659:Closure of skin and subcutaneous tissue of other sites
# 8659:Closure of skin and subcutaneous tissue of other sites
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8730:Open wound of scalp:Open wound of scalp, without mention of complication
# 8500:Concussion w/o coma:Concussion with no loss of consciousness
# ========== PRS ==========
# 8876:Diagnostic ultrasound of abdomen and retroperitoneum
# 8703:Computerized axial tomography of head
# 8802:Other abdomen tomography
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 86229:Intrathoracic inj NEC-cl:Injury to other specified intrathoracic organs without mention of open wound into cavity
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 81600:Fx phalanx, hand NOS-cl:Closed fracture of phalanx or phalanges of hand, unspecified
# 8072:Fracture of sternum-clos:Closed fracture of sternum
# 80709:Fx mult ribs NOS-closed:Closed fracture of multiple ribs, unspecified
# ========== PRS ==========
# <UNK>:Unknown Code
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 81221:Fx humerus shaft-closed:Closed fracture of shaft of humerus
# 86500:Spleen injury NOS-closed:Injury to spleen without mention of open wound into cavity, unspecified injury
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 86803:Peritoneum injury-closed:Injury to other intra-abdominal organs without mention of open wound into cavity, peritoneum
# 81342:Fx distal radius NEC-cl:Other closed fractures of distal end of radius (alone)
# 8240:Fx medial malleolus-clos:Fracture of medial malleolus, closed
# 8500:Concussion w/o coma:Concussion with no loss of consciousness
# 81501:Fx 1st metacarp base-cl:Closed fracture of base of thumb [first] metacarpal
# 81343:Fx distal ulna-closed:Closed fracture of distal end of ulna (alone)
# 88101:Open wound of elbow:Open wound of elbow, without mention of complication
# 87342:Open wound of forehead:Open wound of forehead, without mention of complication
# 80701:Fracture one rib-closed:Closed fracture of one rib
# 3051:Tobacco use disorder:Tobacco use disorder
# ========== PRS ==========
# 0881:Linear repair of laceration of eyelid or eyebrow
# 415:Total splenectomy
# 5411:Exploratory laparotomy
# 8472:Application of external fixator device, ring system
# 8659:Closure of skin and subcutaneous tissue of other sites
# 9921:Injection of antibiotic
# 8471:Application of external fixator device, monoplanar system
# 7901:Closed reduction of fracture without internal fixation, humerus
# 7812:Application of external fixator device, humerus
# 7817:Application of external fixator device, tibia and fibula
# ========== END ==========
#
# ========= START =========
# ========== DXS ==========
# 8500:Concussion w/o coma:Concussion with no loss of consciousness
# 8470:Sprain of neck:Sprain of neck
# ========== PRS ==========
# 8826:Other skeletal x-ray of pelvis and hip
# 8801:Computerized axial tomography of abdomen
# 8703:Computerized axial tomography of head
# 8838:Other computerized axial tomography
# 8741:Computerized axial tomography of thorax
# 8744:Routine chest x-ray, so described
# ========== END ==========

# %%
get_seq_dsc(e8120_trn_seq[0])
# Out:
# ========= START =========
# ========== DXS ==========
# 8600:Traum pneumothorax-close:Traumatic pneumothorax without mention of open wound into thorax
# 80702:Fracture two ribs-closed:Closed fracture of two ribs
# ========== PRS ==========
# 9352:Application of neck support
# 8801:Computerized axial tomography of abdomen
# 8741:Computerized axial tomography of thorax
# ========== END ==========

# %%
search('E812.0')
# Out:
# E8120:Mv collision NOS-driver:Other motor vehicle traffic accident involving collision with motor vehicle injuring driver of motor vehicle other than motorcycle

# %% [markdown]
# We have the intuition that given a distribution with center of the hyper-elliposid $c$ and the shape of the ellipsoid defined by $\Sigma$, $c$ and $\sigma$ should not deviate from the empirical mean ($\hat{c}$) and the covariance estimations ($\hat{\Sigma}$) taken from the training data.
#
# To obtain these estimates we need to:
#
# 1. Feed the NTDB model with the training data (length $n$) and from the last token get the features of each layer ($n$ x 13 x 768)
# 1. Calculate the sample mean ($\hat{c}$) and the covariance estimate ($\hat{\Sigma}$), while also getting the estimated pseudo-inverse (called `.precision_` in sklearn)
#
# To obtain the OOD estimation we need to:
#
# 1. Calculate the Mahalanobis Distance Feature (MDF) using the generated data (should be a vector equal to the number of layers)
# 1. Calculate the Anomaly Score
#   1. This is a one-class SVM with a linear kernel with MDF as features

# %%
def get_hidden_embeddings(hidden_states, use_last=True):
    _start = torch.squeeze(torch.stack(hidden_states[0]).transpose(0,2), dim=1)
    _hs = torch.stack([torch.reshape(torch.stack(x), [13, 768]) for x in hidden_states[1:]])
    
    _em = torch.concat([_start, _hs])
    if use_last:
        return _em[-1, :, :]
    else:
        return _em

# %%
def get_embeddings(sequences, use_last=True):
    last_token_layer_embeddings = []
    for seq in tqdm.tqdm(sequences):
        out = NTDBGPT2_lm.generate(
            NTDBGPT2_tokenizer.encode(seq, return_tensors='pt'),
            do_sample=True,
            #min_length=10,
            #max_length=12,
            #top_p=0.9, 
            top_k=0,
            return_dict_in_generate=True,
            forced_eos_token_id=NTDBGPT2_tokenizer.eos_token_id,
            #repetition_penalty=3.0,
            #length_penalty=1.0,
            #num_return_seqs=1,
            output_hidden_states=True
        )
        last_token_layer_embeddings.append(get_hidden_embeddings(out.hidden_states, use_last))
    if use_last:
        return torch.stack(last_token_layer_embeddings)
    else:
        return last_token_layer_embeddings

# %% [markdown]
# #### Get Sequence Embeddings of All Layers

# %%
#e8120_trn_all_token_layer_embeddings = get_embeddings(e8120_trn_seq, use_last=False)
#e8120_gen_all_token_layer_embeddings = get_embeddings(e8120_gen_seq, use_last=False)
#np.save("./outputs/e8120_trn_all_em.npy", e8120_trn_all_token_layer_embeddings)
#np.save("./outputs/e8120_gen_all_em.npy", e8120_gen_all_token_layer_embeddings)

#e8120_trn_end_token_layer_embeddings = torch.stack([x[-1,:,:] for x in e8120_trn_all_token_layer_embeddings])
#np.save("./outputs/e8120_trn_end_em.npy", e8120_trn_end_token_layer_embeddings)
#e8120_gen_end_token_layer_embeddings = torch.stack([x[-1,:,:] for x in e8120_gen_all_token_layer_embeddings])
#np.save("./outputs/e8120_gen_end_em.npy", e8120_gen_end_token_layer_embeddings)

# %%
#e8859_trn_all_token_layer_embeddings = get_embeddings(e8859_trn_seq, use_last=False)
#e8859_gen_all_token_layer_embeddings = get_embeddings(e8859_gen_seq, use_last=False)
#np.save("./outputs/e8859_trn_all_em.npy", e8859_trn_all_token_layer_embeddings)
#np.save("./outputs/e8859_gen_all_em.npy", e8859_gen_all_token_layer_embeddings)

#e8859_trn_end_token_layer_embeddings = torch.stack([x[-1,:,:] for x in e8859_trn_all_token_layer_embeddings])
#np.save("./outputs/e8859_trn_end_em.npy", e8859_trn_end_token_layer_embeddings)

#e8859_gen_end_token_layer_embeddings = torch.stack([x[-1,:,:] for x in e8859_gen_all_token_layer_embeddings])
#np.save("./outputs/e8859_gen_end_em.npy", e8859_gen_end_token_layer_embeddings)

# %%
#e9660_trn_all_token_layer_embeddings = get_embeddings(e9660_trn_seq, use_last=False)
#e9660_gen_all_token_layer_embeddings = get_embeddings(e9660_gen_seq, use_last=False)
#np.save("./outputs/e9660_trn_all_em.npy", e9660_trn_all_token_layer_embeddings)
#np.save("./outputs/e9660_gen_all_em.npy", e9660_gen_all_token_layer_embeddings)

#e9660_trn_end_token_layer_embeddings = torch.stack([x[-1,:,:] for x in e9660_trn_all_token_layer_embeddings])
#np.save("./outputs/e9660_trn_end_em.npy", e9660_trn_end_token_layer_embeddings)

#e9660_gen_end_token_layer_embeddings = torch.stack([x[-1,:,:] for x in e9660_gen_all_token_layer_embeddings])
#np.save("./outputs/e9660_gen_end_em.npy", e9660_gen_end_token_layer_embeddings)
# Out:
# 100%|███████████████████████████████████████████████████████████| 5000/5000 [13:52<00:00,  6.01it/s]
# 100%|███████████████████████████████████████████████████████████| 5000/5000 [12:36<00:00,  6.61it/s]
# /home/paul/anaconda3/envs/stemmler/lib/python3.8/site-packages/numpy/lib/npyio.py:528: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   arr = np.asanyarray(arr)
# /home/paul/anaconda3/envs/stemmler/lib/python3.8/site-packages/numpy/lib/npyio.py:528: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)
